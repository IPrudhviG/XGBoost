# %% [markdown]
# Prediction of Forest Cover Type using XGBoost

# %%
#Import all the dependencies
import xgboost as xgb
from sklearn.datasets import fetch_covtype #Forest covtype is dataset of multi-class classification
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
#Get data using sklearn datasets
data = fetch_covtype(as_frame=True)
# data

# %%
#Define features and target from the dataset
X = data.data
y = data.target

# %%
#Print the features first five rows to view the data
X.head()

# %%
#Encoding the cataegorical variables 
e = LabelEncoder()
ynew = e.fit_transform(y)

# %%
#Split train and test data, test size is 20 percent and train is 80 percent
xtrain, xtest, ytrain, ytest = train_test_split(X,ynew, test_size= 0.2, random_state= 42)

# %%
#Build model
model = xgb.XGBClassifier(
    objective='multi:softmax',
    num_class = 7,
    n_estimators = 100,
    max_depth = 6,
    learning_rate =0.1,
    subsample = 0.8,
    colsample_bytree = 0.8,
    early_stopping_rounds=10,
    random_state = 42
)

# %%
#Fit the model with traindata
model.fit(
    xtrain,ytrain,
    eval_set=[(xtest,ytest)],
    verbose=True)
# Out:
# [0]	validation_0-mlogloss:1.75951
# [1]	validation_0-mlogloss:1.62840
# [2]	validation_0-mlogloss:1.50944
# [3]	validation_0-mlogloss:1.40690
# [4]	validation_0-mlogloss:1.32478
# [5]	validation_0-mlogloss:1.25304
# [6]	validation_0-mlogloss:1.18553
# [7]	validation_0-mlogloss:1.12574
# [8]	validation_0-mlogloss:1.07936
# [9]	validation_0-mlogloss:1.03193
# [10]	validation_0-mlogloss:0.99015
# [11]	validation_0-mlogloss:0.95427
# [12]	validation_0-mlogloss:0.91867
# [13]	validation_0-mlogloss:0.88842
# [14]	validation_0-mlogloss:0.85929
# [15]	validation_0-mlogloss:0.83440
# [16]	validation_0-mlogloss:0.80938
# [17]	validation_0-mlogloss:0.78695
# [18]	validation_0-mlogloss:0.76799
# [19]	validation_0-mlogloss:0.75121
# [20]	validation_0-mlogloss:0.73439
# [21]	validation_0-mlogloss:0.71910
# [22]	validation_0-mlogloss:0.70393
# [23]	validation_0-mlogloss:0.69048
# [24]	validation_0-mlogloss:0.67709
# [25]	validation_0-mlogloss:0.66447
# [26]	validation_0-mlogloss:0.65382
# [27]	validation_0-mlogloss:0.64362
# [28]	validation_0-mlogloss:0.63466
# [29]	validation_0-mlogloss:0.62561
# [30]	validation_0-mlogloss:0.61721
# [31]	validation_0-mlogloss:0.60916
# [32]	validation_0-mlogloss:0.60155
# [33]	validation_0-mlogloss:0.59465
# [34]	validation_0-mlogloss:0.58803
# [35]	validation_0-mlogloss:0.58201
# [36]	validation_0-mlogloss:0.57658
# [37]	validation_0-mlogloss:0.57085
# [38]	validation_0-mlogloss:0.56544
# [39]	validation_0-mlogloss:0.56012
# [40]	validation_0-mlogloss:0.55561
# [41]	validation_0-mlogloss:0.55064
# [42]	validation_0-mlogloss:0.54626
# [43]	validation_0-mlogloss:0.54228
# [44]	validation_0-mlogloss:0.53842
# [45]	validation_0-mlogloss:0.53454
# [46]	validation_0-mlogloss:0.53129
# [47]	validation_0-mlogloss:0.52700
# [48]	validation_0-mlogloss:0.52398
# [49]	validation_0-mlogloss:0.52120
# [50]	validation_0-mlogloss:0.51802
# [51]	validation_0-mlogloss:0.51528
# [52]	validation_0-mlogloss:0.51266
# [53]	validation_0-mlogloss:0.51017
# [54]	validation_0-mlogloss:0.50814
# [55]	validation_0-mlogloss:0.50603
# [56]	validation_0-mlogloss:0.50368
# [57]	validation_0-mlogloss:0.50150
# [58]	validation_0-mlogloss:0.49929
# [59]	validation_0-mlogloss:0.49636
# [60]	validation_0-mlogloss:0.49457
# [61]	validation_0-mlogloss:0.49219
# [62]	validation_0-mlogloss:0.49017
# [63]	validation_0-mlogloss:0.48854
# [64]	validation_0-mlogloss:0.48640
# [65]	validation_0-mlogloss:0.48513
# [66]	validation_0-mlogloss:0.48358
# [67]	validation_0-mlogloss:0.48221
# [68]	validation_0-mlogloss:0.48013
# [69]	validation_0-mlogloss:0.47811
# [70]	validation_0-mlogloss:0.47692
# [71]	validation_0-mlogloss:0.47576
# [72]	validation_0-mlogloss:0.47438
# [73]	validation_0-mlogloss:0.47292
# [74]	validation_0-mlogloss:0.47152
# [75]	validation_0-mlogloss:0.47043
# [76]	validation_0-mlogloss:0.46934
# [77]	validation_0-mlogloss:0.46839
# [78]	validation_0-mlogloss:0.46692
# [79]	validation_0-mlogloss:0.46545
# [80]	validation_0-mlogloss:0.46434
# [81]	validation_0-mlogloss:0.46317
# [82]	validation_0-mlogloss:0.46234
# [83]	validation_0-mlogloss:0.46150
# [84]	validation_0-mlogloss:0.46051
# [85]	validation_0-mlogloss:0.45963
# [86]	validation_0-mlogloss:0.45848
# [87]	validation_0-mlogloss:0.45730
# [88]	validation_0-mlogloss:0.45628
# [89]	validation_0-mlogloss:0.45531
# [90]	validation_0-mlogloss:0.45435
# [91]	validation_0-mlogloss:0.45336
# [92]	validation_0-mlogloss:0.45224
# [93]	validation_0-mlogloss:0.45140
# [94]	validation_0-mlogloss:0.45059
# [95]	validation_0-mlogloss:0.44990
# [96]	validation_0-mlogloss:0.44852
# [97]	validation_0-mlogloss:0.44685
# [98]	validation_0-mlogloss:0.44628
# [99]	validation_0-mlogloss:0.44502
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=10,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None, num_class=7,
#               num_parallel_tree=None, ...)

# %%
#Predict and evaluate
ypred = model.predict(xtest)

# %%
#Determine accuracy of the model
accuracy = accuracy_score(ytest,ypred)
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# Test Accuracy: 0.8149
